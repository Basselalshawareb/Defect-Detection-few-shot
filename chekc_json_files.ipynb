# %%
import json
file = json.load(open("/home/huemorgen/DefectDetection/datasets/NEU_DET/traintest/train.json"))
len(file['annotations'])
# Out:
# 480

# %%
file = json.load(open("/home/huemorgen/DefectDetection/datasets/NEU_DET/traintest/test.json"))
len(file['annotations'])
# Out:
# 3709

# %%
file['annotations']
# Out:
# [{'area': 11343,
#   'iscrowd': 0,
#   'bbox': [75, 0, 57, 199],
#   'category_id': 3,
#   'ignore': 0,
#   'segmentation': [],
#   'image_id': 1363333,
#   'id': 1524},
#  {'area': 729,
#   'iscrowd': 0,
#   'bbox': [150, 135, 27, 27],
#   'category_id': 3,
#   'ignore': 0,
#   'segmentation': [],
#   'image_id': 2833333,
#   'id': 1755},
#  {'area': 10600,
#   'iscrowd': 0,
#   'bbox': [0, 46, 200, 53],
#   'category_id': 1,
#   'ignore': 0,
#   'segmentation': [],
#   'image_id': 351111,
#   'id': 1659},
#  {'area': 37054,
#   'iscrowd': 0,
#   'bbox': [3, 8, 194, 191],
#   'category_id': 4,
#   'ignore': 0,
#   'segmentation': [],
#   'image_id': 2504444,
#   'id': 1919},
#  {'area': 9675,
#   'iscrowd': 0,
#   'bbox': [49, 116, 129, 75],
#   'category_id': 1,
#   'ignore': 0,
#   'segmentation': [],
#   'image_id': 1351111,
#   'id': 2662},
#  {'area': 1280,
#   'iscrowd': 0,
#   'bbox': [101, 156, 32, 40],
#   'category_id': 3,
#   'ignore': 0,
#   'segmentation': [],
# ...
